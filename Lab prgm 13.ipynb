# %%
## Libraries Required
# !pip install langchain-huggingface
## For API Calls
# !pip install huggingface_hub # For models
# !pip install transformers # Hugging face libraray for transformers
# !pip install accelerate # For distributed training
# !pip install  bitsandbytes # For quantization
# !pip install langchain
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.3/61.3 MB 17.0 MB/s eta 0:00:00
# ...

# %%
## Environment secret keys
from google.colab import userdata
sec_key=userdata.get("HF_TOKEN")
print(sec_key)
# Out:
# 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

# %%
#!pip install langchain-huggingface
from langchain_huggingface import HuggingFaceEndpoint

# %%
from google.colab import userdata
sec_key=userdata.get("HUGGINGFACEHUB_API_TOKEN")
print(sec_key)
# Out:
# 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

# %%
import os
os.environ["HUGGINGFACEHUB_API_TOKEN"]=sec_key

# %%
# !pip install langchain-huggingface
# !pip install huggingface_hub

from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint
import os
from google.colab import userdata

# Load Hugging Face token
sec_key = userdata.get("HUGGINGFACEHUB_API_TOKEN")
os.environ["HUGGINGFACEHUB_API_TOKEN"] = sec_key

# For conversational models (like mistralai/Mistral-7B-Instruct-v0.3)
llm = HuggingFaceEndpoint(
    repo_id="mistralai/Mistral-7B-Instruct-v0.3",
    task="conversational",   # <-- important!
    temperature=0.7
)

chat_llm = ChatHuggingFace(llm=llm)

# Now invoke
resp = chat_llm.invoke("What is Generative AI?")
print(resp.content)
# Out:
# ...
#  Generative AI is a type of artificial intelligence that can create new content, such as images, text, music, or even speech, by learning patterns from a large dataset and then generating output that resembles the original data. It's called "generative" because it generates new data rather than just processing or classifying existing data like other AI models.
#
# Generative AI models are trained using a technique called generative adversarial networks (GANs), variational autoencoders (VAEs), or other similar methods. These models consist of two parts: a generator and a discriminator. The generator creates new data, while the discriminator tries to distinguish the generated data from real data. Over time, the generator improves by learning to create more convincing data that the discriminator can't tell apart from real data.
#
# Some examples of generative AI include:
#
# ...
